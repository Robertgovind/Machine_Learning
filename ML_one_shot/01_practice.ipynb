# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"loan_data.csv")
dataset.head(5)
# Out:
#    credit.policy             purpose int.rate installment log.annual.inc  \
# 0              1  debt_consolidation   0.1189                11.35040654
# 1              1         credit_card   0.1071      228.22    11.08214255
# 2              1  debt_consolidation   0.1357      366.86    10.37349118
# 3              1  debt_consolidation   0.1008      162.34    11.35040654
# 4              1         credit_card   0.1426      102.92    11.29973224
#
#      dti  fico days.with.cr.line revol.bal revol.util inq.last.6mths  \
# 0  19.48   737       5639.958333     28854       52.1              0
# 1          707              2760     33623       76.7              0
# 2  11.63   682              4710      3511       25.6              1
# 3    8.1   712       2699.958333     33667       73.2              1
# 4    NaN   667              4066      4740       39.5              0
#
#    delinq.2yrs pub.rec not.fully.paid
# 0            0       0              0
# ...

# %%
dataset2 = pd.read_csv(r"Pharmacies.csv")  #directly called as file is in same locationS
dataset2.head(5)
# Out:
# C:\Users\govin\AppData\Local\Temp\ipykernel_20188\2807974496.py:1: DtypeWarning: Columns (33,34,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset2 = pd.read_csv(r"Pharmacies.csv")  #directly called as file is in same locationS
#     FID        ID      SECCLASS                                        NAME  \
# 0  1001  11699187  UNCLASSIFIED                      MOWRY MEDICAL PHARMACY
# 1  1002  11699219  UNCLASSIFIED                        MOWRY PLAZA PHARMACY
# 2  1003  11698012  UNCLASSIFIED  KAISER PERMANENTE DALY CITY MEDICAL OFFICE
# 3  1004  11697767  UNCLASSIFIED      KAISER PERMANENTE TRACY MEDICAL OFFICE
# 4  1005  11666870  UNCLASSIFIED                           WALGREENS - 13596
#
#       TELEPHONE                    ADDRESS     ADDRESS2       CITY STATE  \
# 0  510-793-5011          1999 MOWRY AVENUE     SUITE 2A    FREMONT    CA
# 1  510-745-9900           668 MOWRY AVENUE                 FREMONT    CA
# ...

# %%
dataset.shape
# Out:
# (9578, 14)

# %%
dataset.isnull()
# Out:
#       credit.policy  purpose  int.rate  installment  log.annual.inc    dti  \
# 0             False    False     False        False           False  False
# 1             False    False     False        False           False  False
# 2             False    False     False        False           False  False
# 3             False    False     False        False           False  False
# 4             False    False     False        False           False   True
# ...             ...      ...       ...          ...             ...    ...
# 9573          False    False     False        False           False  False
# 9574          False    False     False        False           False  False
# 9575          False    False     False        False           False  False
# 9576          False    False     False        False           False  False
# 9577          False    False     False        False           False  False
#
# ...

# %%
dataset.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  1
# fico                 0
# days.with.cr.line    1
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
sns.heatmap(dataset.isna())
plt.show()
