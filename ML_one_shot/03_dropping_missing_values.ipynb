# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"loan_data.csv")
dataset.head(5)
# Out:
#    credit.policy             purpose int.rate installment log.annual.inc  \
# 0              1  debt_consolidation   0.1189                11.35040654
# 1              1         credit_card   0.1071      228.22    11.08214255
# 2              1  debt_consolidation   0.1357      366.86    10.37349118
# 3              1  debt_consolidation   0.1008      162.34    11.35040654
# 4              1         credit_card   0.1426      102.92    11.29973224
#
#      dti  fico days.with.cr.line revol.bal revol.util inq.last.6mths  \
# 0  19.48   737       5639.958333     28854       52.1              0
# 1          707              2760     33623       76.7              0
# 2  11.63   682              4710      3511       25.6              1
# 3    8.1   712       2699.958333     33667       73.2              1
# 4    NaN   667              4066      4740       39.5              0
#
#    delinq.2yrs pub.rec not.fully.paid
# 0            0       0              0
# ...

# %%
dataset.shape
# Out:
# (9578, 14)

# %%
dataset.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  1
# fico                 0
# days.with.cr.line    1
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
#inplace is used to replace deleted coluumn
dataset.drop(columns=["dti"],inplace=True)

# %%
#dti column is dropped
dataset.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# fico                 0
# days.with.cr.line    1
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
dataset.shape
# Out:
# (9578, 13)

# %%
#drops all row having missing values
dataset.dropna(inplace=True)

# %%
dataset.shape
# Out:
# (9577, 13)

# %%
#all missing values row are dropped
sns.heatmap(dataset.isnull())
plt.show()
