# %%
import pandas as pd

# %%
# Reading csv(comma separated value) file
# We can use double backslash while providing path of csv file
dataset = pd.read_csv(r"health_rankings.csv")
dataset.head(10)
# Out:
#   State         County  State code  County code  Year span  \
# 0    US  United States         0.0          0.0  2003-2005
# 1    US  United States         0.0          0.0  2004-2006
# 2    US  United States         0.0          0.0  2005-2007
# 3    US  United States         0.0          0.0  2006-2008
# 4    US  United States         0.0          0.0  2007-2009
# 5    US  United States         0.0          0.0  2008-2010
# 6    US  United States         0.0          0.0  2009-2011
# 7    AL        Alabama         1.0          0.0  2003-2005
# 8    AL        Alabama         1.0          0.0  2004-2006
# 9    AL        Alabama         1.0          0.0  2005-2007
#
#          Measure name  Measure id     Numerator   Denominator   Raw value  \
# 0  Violent crime rate        43.0  1.328751e+06  2.748771e+08  483.398066
# 1  Violent crime rate        43.0  1.340929e+06  2.776128e+08  483.021233
# 2  Violent crime rate        43.0  1.355853e+06  2.804077e+08  483.529230
# ...

# %%
dataset1 = pd.read_csv(r"health_rankings.csv",nrows=2)
dataset1
# Out:
#   State         County  State code  County code  Year span  \
# 0    US  United States           0            0  2003-2005
# 1    US  United States           0            0  2004-2006
#
#          Measure name  Measure id    Numerator  Denominator   Raw value  \
# 0  Violent crime rate          43  1328750.667  274877117.0  483.398066
# 1  Violent crime rate          43  1340928.667  277612778.5  483.021233
#
#    Confidence Interval Lower Bound  Confidence Interval Upper Bound  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
#
#    Data Release Year  fipscode
# 0                NaN         0
# 1                NaN         0

# %%
print(type(dataset1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
dataset1 = pd.read_csv(r"health_rankings.csv",usecols=[0,1,2])
dataset1
# Out:
#        State         County  State code
# 0         US  United States         0.0
# 1         US  United States         0.0
# 2         US  United States         0.0
# 3         US  United States         0.0
# 4         US  United States         0.0
# ...      ...            ...         ...
# 303859    WY  Weston County        56.0
# 303860    WY  Weston County        56.0
# 303861    WY  Weston County        56.0
# 303862    WY  Weston County        56.0
# 303863    WY  Weston County        56.0
#
# [303864 rows x 3 columns]

# %%
dataset.isnull().sum()
# Out:
# State                                   6
# County                                  6
# State code                              4
# County code                             4
# Year span                             474
# Measure name                          474
# Measure id                            474
# Numerator                           89788
# Denominator                        119085
# Raw value                           13908
# Confidence Interval Lower Bound    114452
# Confidence Interval Upper Bound    114452
# Data Release Year                  153735
# fipscode                             9581
# dtype: int64
