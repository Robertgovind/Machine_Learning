# %%
import pandas as pd

# %%
# reading csv file
dataset = pd.read_csv("TB_disease.csv")
dataset.head(5)
# Out:
#   Country or territory name ISO 2-character country/territory code  \
# 0               Afghanistan                                     AF
# 1               Afghanistan                                     AF
# 2               Afghanistan                                     AF
# 3               Afghanistan                                     AF
# 4               Afghanistan                                     AF
#
#   ISO 3-character country/territory code  ISO numeric country/territory code  \
# 0                                    AFG                                   4
# 1                                    AFG                                   4
# 2                                    AFG                                   4
# 3                                    AFG                                   4
# 4                                    AFG                                   4
#
#   Region  Year  Estimated total population number  \
# ...
